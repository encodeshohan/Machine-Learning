# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Data**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X = np.array([30,37,25,43,50,29,46])
y = np.array([800,950,600,1050,1200,740,1100])

# %% [markdown]
# **Plot the data using matplotlib**

# %%
plt.scatter(X,y)

# %% [markdown]
# **Implementing the Model using Gradient Descent**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Building the model
w0 = 300
w1 = 10
learning_rate = 0.0001

epochs = 10  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent
for i in range(epochs):
    y_pred = w0 + w1*X   # The current predicted value of Y
    D_w0 = (2/n) * sum(y_pred - y)  # Derivative wrt w0
    D_w1 = (2/n) * sum(X * (y_pred - y))  # Derivative wrt w1

    w0 = w0 - learning_rate * D_w0  # Update w0
    w1 = w1 - learning_rate * D_w1  # Update w1

    print (w0, w1)
# Out:
# 300.0497142857143 12.038857142857143
# 300.0842728326531 13.48316375510204
# 300.10809533304865 14.506301434001166
# 300.1243126176152 15.231090593618179
# 300.13514251068193 15.744535012604311
# 300.14215607922904 16.108266607423133
# 300.14646623892946 16.36594432238555
# 300.1488613592868 16.548495370658284
# 300.1498999071186 16.677828035397454
# 300.1499774903028 16.769461751485885

# %% [markdown]
# **Compute the predicted values of given data using the learned model**
# <br>Note: It is generally recommended to split the input data into **training and test sets**, allowing the model to be trained on the training set and evaluated on the test set. However, since the goal here is to focus on understanding how linear regression works and how gradient descent is used to learn the parameters, the data split has been omitted in this example.

# %%
predictions = w0 + w1*X
predictions
# Out:
# array([ 803.23383003,  920.6200623 ,  719.38652128, 1021.2368328 ,
#        1138.62306506,  786.46436828, 1071.54521806])

# %% [markdown]
# **Plot the regression line over the input data.**

# %%
plt.scatter(X, y)
plt.plot(X, predictions, color='red')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear regression')
plt.show()
